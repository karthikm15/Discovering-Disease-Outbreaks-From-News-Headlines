# %%
import pandas as pd
import geonamescache
df = pd.read_csv('ParsingNewsHeadlines.csv')
gnc = geonamescache.GeonamesCache()
arrlat = []
arrlong = []
arrcountry = []
for ind in df.index:
    if (df['cities'][ind] == "NaN" or gnc.get_cities_by_name(df['cities'][ind]) == []):
        arrlat.append("NaN")
        arrlong.append("NaN")
        arrcountry.append("NaN")
    else: 
        city_thing = [k for k in gnc.get_cities_by_name(df['cities'][ind])[0]]
        #print (city_thing)
        max1 = 0;
        index = 0;
        for i in range(len(city_thing)):
            thing = city_thing[i]
            if (max1 <= gnc.get_cities_by_name(df['cities'][ind])[i][thing]['population']):
                max1 = gnc.get_cities_by_name(df['cities'][ind])[i][thing]['population']
                index = i
        
        city_thing = city_thing[index]
        city_thing = str(city_thing)
        #print(city_thing)
        arrlat.append(gnc.get_cities_by_name(df['cities'][ind])[index][city_thing]['latitude'])
        arrlong.append(gnc.get_cities_by_name(df['cities'][ind])[index][city_thing]['longitude'])
        arrcountry.append(gnc.get_cities_by_name(df['cities'][ind])[index][city_thing]['countrycode'])
        #print(number)
df['latitude'] = arrlat
df['longitude'] = arrlong
df['countrycodes'] = arrcountry
df = df.drop('countries', 1)
df
# Out:
#                                               headline            cities  \
# 0                             Zika Outbreak Hits Miami             Miami
# 1                      Could Zika Reach New York City?     New York City
# 2                    First Case of Zika in Miami Beach       Miami Beach
# 3              Mystery Virus Spreads in Recife, Brazil            Recife
# 4              Dallas man comes down with case of Zika            Dallas
# 5                    Trinidad confirms first Zika case          Trinidad
# 6               Zika Concerns are Spreading in Houston           Houston
# 7                Geneve Scientists Battle to Find Cure               NaN
# 8                The CDC in Atlanta is Growing Worried           Atlanta
# 9                   Zika Infested Monkeys in Sao Paulo               NaN
# 10               Brownsville teen contracts Zika virus       Brownsville
# 11   Mosquito control efforts in St. Louis take new...               NaN
# 12   San Juan reports 1st U.S. Zika-related death a...          San Juan
# 13                    Flu outbreak in Galveston, Texas         Galveston
# 14                  Zika alert – Manila now threatened            Manila
# 15                      Zika afflicts 7 in Iloilo City            Iloilo
# 16                New Los Angeles Hairstyle goes Viral       Los Angeles
# 17                       Louisiana Zika cases up to 26               NaN
# 18                Orlando volunteers aid Zika research           Orlando
# 19                 Zika infects pregnant woman in Cebu               NaN
# 20                 Chicago's First Zika Case Confirmed               NaN
# 21               Tampa Bay Area Zika Case Count Climbs             Tampa
# 22      Bad Water Leads to Sickness in Flint, Michigan             Flint
# 23                      Baltimore plans for Zika virus         Baltimore
# 24           London Health Unit Tracks Mad Cow Disease            London
# 25      Zika cases in Vietnam's Ho Chi Minh City surge  Ho Chi Minh City
# 26                 Philadelphia experts track pandemic      Philadelphia
# 27                              Flu season hits Boston            Boston
# 28             Scientists in Paris to look for answers             Paris
# 29            Key Zika Findings in San Diego Institute         San Diego
# ..                                                 ...               ...
# 620                How to Avoid Chikungunya in Hampton           Hampton
# 621                          Zika Reported in Sao Jose               NaN
# 622            Case of Norovirus Reported in Stratford         Stratford
# 623             How to Avoid Hepatitis E in South Bend        South Bend
# 624                  Hepatitis C Outbreak in Bethlehem         Bethlehem
# 625                  Davenport is infested with Dengue         Davenport
# 626  Rumors about Swine Flu spreading in Suzhou hav...            Suzhou
# 627          Malaria Vaccine is now Required in Elyria            Elyria
# 628                    Zika case reported in Antioquia               NaN
# 629              Case of Swine Flu Reported in Tbilisi           Tbilisi
# 630               Chikungunya has not Left Pismo Beach               NaN
# 631                            Zika spreads to La Joya               NaN
# 632               Influenza Keeps Spreading in Suffolk           Suffolk
# 633  More people in Allentown are infected with Chl...         Allentown
# 634              Mad Cow Disease re-emerges in Bedford           Bedford
# 635  Authorities are Worried about the Spread of He...              Yiwu
# 636                        Zika Outbreak in Yurimaguas        Yurimaguas
# 637                          Dengue Outbreak in Easton            Easton
# 638                    Varicella has Arrived in Milton            Milton
# 639       New medicine wipes out Meningitis in Sevilla           Sevilla
# 640  Authorities are Worried about the Spread of Va...            Clovis
# 641          More Zika patients reported in Fort Worth        Fort Worth
# 642             Zika symptoms spotted in Boynton Beach     Boynton Beach
# 643                     Outbreak of Zika in Portoviejo        Portoviejo
# 644                       Influenza Exposure in Muscat            Muscat
# 645  Rumors about Rabies spreading in Jerusalem hav...         Jerusalem
# 646              More Zika patients reported in Indang            Indang
# 647  Suva authorities confirmed the spread of Rotav...              Suva
# 648         More Zika patients reported in Bella Vista       Bella Vista
# 649                     Zika Outbreak in Wichita Falls     Wichita Falls
#
#     latitude longitude countrycodes
# 0    25.7743  -80.1937           US
# 1    40.7143   -74.006           US
# 2    25.7906    -80.13           US
# 3   -8.05389  -34.8811           BR
# 4    32.7831  -96.8067           US
# 5   -14.8333     -64.9           BO
# 6    29.7633  -95.3633           US
# 7        NaN       NaN          NaN
# 8     33.749   -84.388           US
# 9        NaN       NaN          NaN
# 10   25.8218  -80.2412           US
# 11       NaN       NaN          NaN
# 12  -31.5375  -68.5364           AR
# 13   29.3013  -94.7977           US
# 14   14.6042   120.982           PH
# 15   10.6969   122.564           PH
# 16   34.0522  -118.244           US
# 17       NaN       NaN          NaN
# 18   28.5383  -81.3792           US
# 19       NaN       NaN          NaN
# 20       NaN       NaN          NaN
# 21   27.9475  -82.4584           US
# 22   53.2449  -3.13231           GB
# 23   39.2904  -76.6122           US
# 24   42.9834   -81.233           CA
# 25    10.823    106.63           VN
# 26   39.9523  -75.1638           US
# 27   52.9763  -0.02664           GB
# 28   48.8534    2.3488           FR
# 29   9.89898  -84.0029           CR
# ..       ...       ...          ...
# 620  51.4133  -0.36701           GB
# 621      NaN       NaN          NaN
# 622  43.3668  -80.9497           CA
# 623  41.6834    -86.25           US
# 624  31.7049   35.2038           PS
# 625  41.5236  -90.5776           US
# 626  33.6361   116.979           CN
# 627  41.3684  -82.1077           US
# 628      NaN       NaN          NaN
# 629  41.6941   44.8337           GE
# 630      NaN       NaN          NaN
# 631      NaN       NaN          NaN
# 632  36.7284   -76.585           US
# 633  40.6084  -75.4902           US
# 634  52.1346  -0.46632           GB
# 635  29.3151   120.077           CN
# 636 -5.90181  -76.1223           PE
# 637  38.7743  -76.0763           US
# 638  43.5168  -79.8829           CA
# 639  4.26425  -75.9309           CO
# 640  36.8252  -119.703           US
# 641  32.7254  -97.3208           US
# 642  26.5253  -80.0664           US
# 643 -1.05458  -80.4544           EC
# 644  23.5841   58.4078           OM
# 645   31.769   35.2163           IL
# 646  14.1953   120.877           PH
# 647 -18.1416   178.441           FJ
# 648 -27.0342   -65.302           AR
# 649  33.9137  -98.4934           US
#
# [650 rows x 5 columns]
